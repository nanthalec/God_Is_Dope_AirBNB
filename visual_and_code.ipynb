# %% [markdown]
# Import and Install Packages and Libraries

# %%
import numpy as np 
import pandas as pd

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pd.set_option('precision', 0)

# %%
sns.set(rc={'figure.figsize': (16,3)})

# %% [markdown]
# Import dataframe
# (data columns cleaned in excel)

# %%
reviews = pd.read_csv('/Users/galvanize/Desktop/capstone_2/Final_clean_data/reviews_final.csv')

# %%
calendar_full = pd.read_csv('/Users/galvanize/Desktop/capstone_2/Final_clean_data/calendar.csv')

# %%
calendar2 = pd.read_csv('/Users/galvanize/Desktop/capstone_2/Final_clean_data/calendar_revised.csv')

# %%
listing2 = pd.read_csv('/Users/galvanize/Desktop/capstone_2/Final_clean_data/small_listing_final.csv')

# %%
listing = pd.read_csv('/Users/galvanize/Desktop/capstone_2/Final_clean_data/oakland_revised.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# LISTING
# Cleaning of rows/ blank
#
# Checking out the data to find nulls
#
# Determine if rows with mult. nulls to be deleted with threshold of 20%

# %% [markdown]
# # Data Cleaning listings

# %%
#listing.shape
listing.info()
#listing.zipcode.dtype
# Out:
# dtype('float64')

# %%
listing.tail(50)
# Out:
#             id last_scraped  \
# 3231  43169702      5/18/20
# 3232  43179244      5/18/20
# 3233  43187437      5/19/20
# 3234  43188919      5/18/20
# 3235  43191093      5/19/20
# 3236  43197687      5/18/20
# 3237  43198712      5/18/20
# 3238  43206074      5/18/20
# 3239  43206865      5/19/20
# 3240  43207067      5/18/20
# 3241  43213598      5/19/20
# 3242  43229233      5/18/20
# 3243  43235195      5/18/20
# 3244  43265917      5/18/20
# 3245  43269426      5/18/20
# 3246  43269480      5/19/20
# 3247  43276256      5/18/20
# 3248  43278215      5/19/20
# 3249  43286475      5/18/20
# 3250  43294410      5/19/20
# 3251  43295722      5/18/20
# 3252  43302330      5/19/20
# 3253  43303120      5/18/20
# 3254  43330593      5/19/20
# 3255  43330889      5/19/20
# 3256  43335404      5/18/20
# 3257  43335533      5/18/20
# 3258  43336530      5/18/20
# 3259  43342122      5/18/20
# 3260  43342483      5/18/20
# 3261  43346835      5/18/20
# 3262  43347509      5/19/20
# ...

# %%
listing.head(50)

# %%
pd.options.display.max_rows = 999

# %%
listing.isna().sum()
# Out:
# id                                                 0
# last_scraped                                       0
# listing_name                                       0
# city                                               0
# zipcode                                           23
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                          2
# bedrooms                                           4
# beds                                              18
# bed_type                                           0
# square_feet                                     3249
# price_daily                                       77
# price_weekly                                    2813
# price_monthly                                   2946
# ...

# %%
listing.zipcode.fillna('12345')
# Out:
# 0       9e+04
# 1       9e+04
# 2       9e+04
# 3       9e+04
# 4       9e+04
#         ...
# 3276    9e+04
# 3277    9e+04
# 3278    9e+04
# 3279    9e+04
# 3280    9e+04
# Name: zipcode, Length: 3281, dtype: object

# %%
listing['zipcode']=listing['zipcode'].apply(str)

# %% [markdown]
# # Listings: Replace NA/Drop Columns

# %% [markdown]
# We need the values for these colums
# We will replace the NAN with the mean value inorder to preserve the data

# %%
listing[['host_acceptance_rate']].mean()
# Out:
# host_acceptance_rate    8e-01
# dtype: float64

# %%
listing["host_acceptance_rate"].fillna("0.846121", inplace = True)

# %%
listing[['review_scores_rating']].mean()
# Out:
# review_scores_rating    95
# dtype: float64

# %%
listing["review_scores_rating"].fillna("95.052213", inplace = True)

# %%
listing[['reviews_per_month']].mean()
# Out:
# reviews_per_month    1
# dtype: float64

# %%
listing["reviews_per_month"].fillna("1.350773", inplace = True)

# %%
listing[['review_scores_value']].mean()
# Out:
# review_scores_value    1
# dtype: float64

# %%
listing["review_scores_value"].fillna("9.531665", inplace = True)

# %%
listing[['review_scores_location']].mean()
# Out:
# review_scores_location    9
# dtype: float64

# %%
listing["review_scores_location"].fillna("9.474782", inplace = True)

# %%
listing[['review_scores_communication']].mean()
# Out:
# review_scores_communication    1
# dtype: float64

# %%
listing["review_scores_communication"].fillna("9.808495", inplace = True)

# %%
listing[['review_scores_checkin']].mean()
# Out:
# review_scores_checkin    1
# dtype: float64

# %%
listing["review_scores_checkin"].fillna("9.844461", inplace = True)

# %%
listing[['review_scores_cleanliness']].mean()
# Out:
# review_scores_cleanliness    1
# dtype: float64

# %%
listing["review_scores_cleanliness"].fillna("9.519136", inplace = True)

# %%
listing[['review_scores_accuracy']].mean()
# Out:
# review_scores_accuracy    1
# dtype: float64

# %%
listing["review_scores_accuracy"].fillna("9.727824", inplace = True)

# %% [markdown]
# Droping Columns

# %%
listing = listing.drop(['host_response_rate'], axis=1)

# %%
listing = listing.drop(['square_feet'], axis=1)

# %% [markdown]
# Turn Zipcode to an object

# %%
listing['zipcode']=listing['zipcode'].apply(str)

# %%
#explored the dataframe one least time

#listing.shape
#listing.describe()
#listing.info()
#listing.head()
listing.columns

# %% [markdown]
# # Cleaning Listing2

# %%
#listing2.shape
#listing2.describe()
#listing2.info()
#listing2.head()
listing2.columns

# %%
listing2.isna().sum()

# %% [markdown]
# Listing2 is clean

# %% [markdown]
# # Limitation client set based on their last takeover:

# %% [markdown]
# 1. Has to be a full house, with 3 bedrooms or more and available over 30 days
# 2. What is the expected prices for these location
# 3. Look at the reviews of the location and analyize findings

# %%
#pd.options.display.max_rows = 999

# %%
#pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Question 1

# %% [markdown]
#  First grouping by zipcode

# %%
pd.options.display.max_rows = 999

# %%
full_home=listing.loc[listing['room_type']=='Entire home/apt']
full_home
# Out:
#             id last_scraped  \
# 1         5739      5/19/20
# 2        11022      5/18/20
# 5        24916      5/18/20
# 6        25473      5/18/20
# 7        29521      5/19/20
# ...        ...          ...
# 3270  43368959      5/19/20
# 3272  43374149      5/18/20
# 3275  43421080      5/18/20
# 3276  43421243      5/18/20
# 3280  43458192      5/18/20
#
#                                            listing_name     city  zipcode  \
# 1                                            Mod Studio  Oakland  94610.0
# 2                     Rockridge Bungalow - Walk to All!  Oakland  94618.0
# 5                   Rockridge Studio w/garden and Patio  Oakland  94611.0
# 6     Luxury Flat w/Mediterranean Garden—Upper Roc...  Oakland  94618.0
# 7                                  Sunny Rockridge Home  Oakland  94618.0
# ...                                                 ...      ...      ...
# 3270        Sunny 1 BR 1 Bath Nearby Schools and Shops!  Oakland  94606.0
# ...

# %% [markdown]
# second group new df by bedroom count 3 and over

# %%
full_home_3=full_home.loc[full_home['bedrooms']>= 3]
full_home_3
# Out:
#             id last_scraped  \
# 8        31573      5/19/20
# 20      151426      5/19/20
# 31      259865      5/18/20
# 32      260659      5/18/20
# 33      275357      5/18/20
# 35      303785      5/18/20
# 36      315467      5/18/20
# 44      470028      5/19/20
# 46      486415      5/18/20
# 49      506630      5/19/20
# 62      620731      5/19/20
# 69      658574      5/18/20
# 93      841127      5/18/20
# 103     972802      5/18/20
# 104     994269      5/18/20
# 111    1080469      5/18/20
# 126    1240861      5/18/20
# 130    1255946      5/18/20
# 135    1288235      5/18/20
# 146    1412799      5/19/20
# 155    1515858      5/19/20
# 190    1919711      5/19/20
# 192    1930986      5/18/20
# 196    1950361      5/19/20
# 204    2028810      5/18/20
# 208    2067909      5/18/20
# 212    2102463      5/19/20
# 213    2164009      5/19/20
# 217    2217748      5/18/20
# 219    2244166      5/18/20
# 234    2543610      5/18/20
# 236    2578332      5/18/20
# ...

# %% [markdown]
# third, group new df available for over 30 days

# %%
# pulled the df I need

listing2.info()
#full_home_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3204 entries, 0 to 3203
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   listing_id        3204 non-null   int64
#  1   name              3204 non-null   object
#  2   host_id           3204 non-null   int64
#  3   host_name         3204 non-null   object
#  4   availability_365  3204 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 125.3+ KB

# %%
# join the two dfs above together
full_home_3_join = full_home_3.join(listing2, lsuffix='_main', rsuffix='_first')

full_home_3_join
# Out:
#             id last_scraped  \
# 8        31573      5/19/20
# 20      151426      5/19/20
# 31      259865      5/18/20
# 32      260659      5/18/20
# 33      275357      5/18/20
# 35      303785      5/18/20
# 36      315467      5/18/20
# 44      470028      5/19/20
# 46      486415      5/18/20
# 49      506630      5/19/20
# 62      620731      5/19/20
# 69      658574      5/18/20
# 93      841127      5/18/20
# 103     972802      5/18/20
# 104     994269      5/18/20
# 111    1080469      5/18/20
# 126    1240861      5/18/20
# 130    1255946      5/18/20
# 135    1288235      5/18/20
# 146    1412799      5/19/20
# 155    1515858      5/19/20
# 190    1919711      5/19/20
# 192    1930986      5/18/20
# 196    1950361      5/19/20
# 204    2028810      5/18/20
# 208    2067909      5/18/20
# 212    2102463      5/19/20
# 213    2164009      5/19/20
# 217    2217748      5/18/20
# 219    2244166      5/18/20
# 234    2543610      5/18/20
# 236    2578332      5/18/20
# ...

# %%
#drop square_feet column
#full_home_3_join = full_home_3_join.drop(['square_feet'], axis=1)

# %%
#work out available over 30 days
available=full_home_3_join.loc[full_home_3_join['availability_365'] >=30]
available
# Out:
#             id last_scraped  \
# 8        31573      5/19/20
# 20      151426      5/19/20
# 33      275357      5/18/20
# 44      470028      5/19/20
# 46      486415      5/18/20
# 49      506630      5/19/20
# 62      620731      5/19/20
# 69      658574      5/18/20
# 93      841127      5/18/20
# 103     972802      5/18/20
# 104     994269      5/18/20
# 126    1240861      5/18/20
# 130    1255946      5/18/20
# 146    1412799      5/19/20
# 190    1919711      5/19/20
# 192    1930986      5/18/20
# 196    1950361      5/19/20
# 212    2102463      5/19/20
# 213    2164009      5/19/20
# 236    2578332      5/18/20
# 238    2600487      5/19/20
# 259    2949486      5/18/20
# 261    2967963      5/19/20
# 262    2979234      5/18/20
# 282    3272426      5/18/20
# 295    3457870      5/18/20
# 297    3466695      5/18/20
# 326    4034215      5/19/20
# 328    4046288      5/19/20
# 341    4137925      5/18/20
# 349    4219040      5/18/20
# 382    4659275      5/18/20
# ...

# %% [markdown]
# Visuals

# %%
# set to white background
sns.set(style="whitegrid")

# %%
#available.zipcode.value_counts()
available.describe()
# Out:
#           id  latitude  longitude  accommodates  bathrooms  bedrooms  beds  \
# count  2e+02     2e+02      2e+02           204      2e+02     2e+02   203
# mean   2e+07     4e+01     -1e+02             7      2e+00     3e+00     4
# std    1e+07     3e-02      4e-02             2      7e-01     8e-01     2
# min    3e+04     4e+01     -1e+02             2      1e+00     3e+00     0
# 25%    8e+06     4e+01     -1e+02             6      2e+00     3e+00     3
# 50%    2e+07     4e+01     -1e+02             6      2e+00     3e+00     4
# 75%    4e+07     4e+01     -1e+02             8      2e+00     4e+00     4
# max    4e+07     4e+01     -1e+02            16      4e+00     8e+00    12
#
#        price_daily  price_weekly  price_monthly  ...  \
# count          204            43             30  ...
# mean           125           852           2631  ...
# std             97           483           1228  ...
# min             19           280           1120  ...
# ...

# %%
sns.set(rc={'figure.figsize': (16,10)})
sns.set(style="whitegrid")

# %%
#top 5 zipcode with the most homes
aa = sns.countplot(x="zipcode",data=available,order=['94611.0','94602.0','94618.0','94609.0','94610.0','94608.0','94607.0'],palette="YlGn")

# %%
#count of available by zipcode
ab = sns.countplot(x = 'zipcode', data = available,palette='YlGn')

# %%
# count by property type
available.property_type.value_counts()
# Out:
# House          162
# Apartment       16
# Bungalow         9
# Condominium      6
# Loft             5
# Chalet           3
# Villa            2
# Townhouse        1
# Name: property_type, dtype: int64

# %%
sns.set(rc={'figure.figsize': (12,5)})

# %%
sns.set(style="whitegrid")

# %%
sns.set(font_scale = 2)

# %%
#visual
ba = sns.countplot(y = 'property_type', data =available,palette="YlGn_r")

# %% [markdown]
# # 2. Price

# %%
sns.set(rc={'figure.figsize': (16,3)})
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
available.columns
# Out:
# Index(['id', 'last_scraped', 'listing_name', 'city', 'zipcode', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'bed_type', 'price_daily', 'price_weekly',
#        'price_monthly', 'security_deposit', 'cleaning_fee',
#        'total_price_daily', 'total_price_weekly', 'total_price_monthly',
#        'minimum_nights', 'maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'property_discription', 'amenities',
#        'reters_notes', 'cancellation_policy', 'about_neighborhood',
#        'neighbourhood', 'neighbourhood_cleansed', 'picture_url',
#        'host_id_main', 'host_name_main', 'host_since', 'host_total_by_year',
#        'about_host', 'host_neighbourhood', 'host_url', 'host_response_time',
#        'host_acceptance_rate', 'host_is_superhost', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
# ...

# %% [markdown]
# *** Total_price_XXX= include cleaning and secrity if any

# %%
c = available['price_daily'].values

# %%
cb = available['total_price_daily'].values

# %%
d = available['price_weekly'].values

# %%
db = available['total_price_weekly'].values

# %%
f = available['price_monthly'].values

# %%
fb = available['total_price_monthly'].values

# %%
#price_daily
sns.boxplot(c,color = '#FBF651')

# %%
# total_price_daily
sns.boxplot(cb,color = '#FBF651')

# %%
#price_weekly
sns.boxplot(d,color = '#0DCDCD')

# %%
#total_price_weekly
sns.boxplot(db,color = '#0DCDCD')

# %%
#price_monthly
sns.boxplot(f,color = '#1BAF77')

# %%
#total_price_monthly
sns.boxplot(fb,color = '#1BAF77')

# %%
mean = available['price_daily'].mean()
mean

sns.distplot(c, color='#FBF651')

plt.axvline(mean,0, 1, color = '000000')

# %%
mean = available['total_price_daily'].mean()
mean

sns.distplot(cb, color='#FBF651')

plt.axvline(mean,0, 1, color = '#000000')

# %%
mean = available['price_weekly'].mean()
mean

sns.distplot(d, color='#BABAB6')

plt.axvline(mean,0, 1, color = 'yellow')

# %%
mean = available['total_price_weekly'].mean()
mean

sns.distplot(db, color='#BABAB6')

plt.axvline(mean,0, 1, color = 'yellow')

# %%
mean = available['price_monthly'].mean()
mean

sns.distplot(f, color='#4A4A49')

plt.axvline(mean,0, 1, color = 'yellow')

# %%
mean = available['total_price_monthly'].mean()
mean

sns.distplot(fb, color='#4A4A49')

plt.axvline(mean,0, 1, color = 'yellow')

# %% [markdown]
# # 3. Reviews

# %% [markdown]
# Look at the reviews of the location and analyize findings

# %%
available.columns
# Out:
# Index(['id', 'last_scraped', 'listing_name', 'city', 'zipcode', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'bed_type', 'price_daily', 'price_weekly',
#        'price_monthly', 'security_deposit', 'cleaning_fee',
#        'total_price_daily', 'total_price_weekly', 'total_price_monthly',
#        'minimum_nights', 'maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'property_discription', 'amenities',
#        'reters_notes', 'cancellation_policy', 'about_neighborhood',
#        'neighbourhood', 'neighbourhood_cleansed', 'picture_url',
#        'host_id_main', 'host_name_main', 'host_since', 'host_total_by_year',
#        'about_host', 'host_neighbourhood', 'host_url', 'host_response_time',
#        'host_acceptance_rate', 'host_is_superhost', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
# ...

# %%
#compaired the avg score for location and the property value to the top 5 zipcode 
#visual done in Tablou"Location Score"

# %%
#compaired the avg review score ratingfor value  and the property value to the top 5 zipcode 
#visual done in Tablou"Review Score"
